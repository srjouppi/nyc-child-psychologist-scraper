# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###  GOAL: Obtain a rate of  mental health providers for child enrollees by region

# %% [markdown]
# #### Load Data

# %%
# Medicaid enrollment by age and region
df1 = pd.read_csv("Medicaid_Program_Enrollment_by_Month___Beginning_2009.csv")

# %%
# Child providers 
df2 = pd.read_csv("child-providers-1.csv")

# %% [markdown]
# #### Clean Data

# %%
# rename columns
df1.columns = df1.columns.str.replace(" ","_").str.lower()
df1.head()
# Out:
#    eligibility_year  eligibility_month   economic_region aid_category  \
# 0              2009                  1  Capital District       FHPLUS
# 1              2009                  1  Capital District       FHPLUS
# 2              2009                  1  Capital District       FHPLUS
# 3              2009                  1  Capital District       FHPLUS
# 4              2009                  1  Capital District       FHPLUS
#
#   dual_eligible managed_care_vs._fee_for_service plan_name plan_type  gender  \
# 0            NO                              MMC     CDPHP  HMO/PHSP  Female
# 1            NO                              MMC     CDPHP  HMO/PHSP  Female
# 2            NO                              MMC     CDPHP  HMO/PHSP  Female
# 3            NO                              MMC     CDPHP  HMO/PHSP  Female
# 4            NO                              MMC     CDPHP  HMO/PHSP  Female
#
#   age_group      race  number_of_recipients
# 0     00-20     ASIAN                     5
# 1     00-20     BLACK                    13
# 2     00-20  HISPANIC                    11
# 3     00-20     OTHER                     3
# 4     00-20     WHITE                    52

# %%
#Let's look only at the most recent numbers from August 2021
df1 = df1[(df1.eligibility_year == 2021) & (df1.eligibility_month == 8)]

# %%
#Add a district column to child provider list using county

# %%
capital = ['GREENE', 'COLUMNIA', 'ALBANY', "RENSSELAER", "SCHENECTADY", "SARATOGA", "WARREN", "WASHINGTON"]
central = ["OSWEGO", "ONONDAGA", "CORTLAND", "MADISON", "CAYUGA"]
western = ["NIAGARA", "ERIE", "CHAUTAUQUA", "CATTARAUGUS", "ALLEGANY"]
finger = ["ORLEANS", "GENESSEE", "WYOMING", "LIVINGSTON", "MONROE", "WAYNE", "ONTARIO", "SENECA", "YATES"]
mohawk = ["ONEIDA", "HERKIMER", "HAMILTON", "FULTON", "MONTGOMERY", "SCHOHARIE"]
north = ["ST. LAWRENCE", "JEFFERSON", "LEWIS", "FRANKLIN", "CLINTON", "ESSEX"]
southern = ["STEUBEN", "SCHUYLER", "TOMPKINS", "CHEMUNG", "TIOGA", "BROOME", "DELAWARE", "OTSEGO", "CHENANGO"]
nyc = ["BRONX", "NEW YORK", "QUEENS", "KINGS", "RICHMOND"]
li = ["NASSAU", "SUFFOLK"]
mid = ["WESTCHESTER", "ROCKLAND", "ORANGE", "SULLIVAN", "ULSTER", "DUTCHESS", "PUTNAM"]

def districtify (county):
    if county in capital:
        return "Capital District"
    elif county in central:
        return "Central"
    elif county in finger:
        return "Finger Lakes"
    elif county in li:
        return "Long Island"
    elif county in mid:
        return "Mid-Hudson"
    elif county in nyc:
        return "New York City"
    elif county in mohawk:
        return "Mohawk Valley"
    elif county in southern:
        return "Southern Tier"
    elif county in north:
        return "North Country"
    elif county in western:
        return "Western"

# %%
df2['economic_region'] = df2.county.apply(districtify)

# %%
df2.head()
# Out:
#    medicaid_provider_id         npi provider_or_facility_name medicaid_type  \
# 0                193339  1609910058    BARNES CYNTHIA DAYNELL           FFS
# 1                232320  1578569364           CANINO IAN A MD          OPRA
# 2                233550  1134359953           DEPAULA ROBERTO           FFS
# 3                314934  1497838296  SHAH MANOJ RAMESHCHANDRA          OPRA
# 4                423294  1861530446         DATTA MOITRI NATH           FFS
#
#   profession_or_service provider_specialty  \
# 0             PHYSICIAN   CHILD PSYCHIATRY
# 1             PHYSICIAN   CHILD PSYCHIATRY
# 2             PHYSICIAN   CHILD PSYCHIATRY
# 3             PHYSICIAN   CHILD PSYCHIATRY
# 4             PHYSICIAN   CHILD PSYCHIATRY
#
#                              service_address       city state_x    zip_code  \
# 0                        352 7TH AVE RM 1109   NEW YORK      NY  10001-5012
# 1                   1051 RIVERSIDE DR # 1812   NEW YORK      NY  10032-1007
# 2                               1249 5TH AVE   NEW YORK      NY  10029-4413
# 3  1 BROOKDALE PLZ BROOKDALE HOSP MED CENTER   BROOKLYN      NY  11212-3139
# 4                             100 N BROADWAY  IRVINGTON      NY  10533-1254
#
#    ... enrollment_begin_date  next_anticipated_revalidation_date   file_date  \
# 0  ...            07/01/2004                          04/01/2024  02/28/2022
# 1  ...            10/01/2013                          09/15/2019  02/28/2022
# 2  ...            12/13/2013                          07/01/2023  02/28/2022
# 3  ...            05/17/2017                          01/11/2024  02/28/2022
# 4  ...            12/03/1979                          09/15/2026  02/28/2022
#
#    medically_fragile_children_directory_ind provider_email primary_taxonomy  \
# 0                                         N            NaN              Yes
# 1                                         N            NaN              Yes
# 2                                         N            NaN              Yes
# 3                                         N            NaN              Yes
# 4                                         N            NaN              Yes
#
#                                    selected_taxonomy state_y  license_number  \
# 0  2084P0804X  - Psychiatry & Neurology Child & A...      NY          109110
# 1  2084P0804X  - Psychiatry & Neurology Child & A...      NY          123507
# 2  2084P0804X  - Psychiatry & Neurology Child & A...      NY          124580
# 3  2084P0804X  - Psychiatry & Neurology Child & A...      NY          135666
# 4  2084P0804X  - Psychiatry & Neurology Child & A...      NY          138997
#
#   economic_region
# 0   New York City
# 1   New York City
# 2   New York City
# 3   New York City
# 4      Mid-Hudson
#
# [5 rows x 24 columns]

# %% [markdown]
# #### How many mental health providers by region?
# First let's look at the total, indescriminate of specialty

# %%
df2.economic_region.value_counts()
# Out:
# New York City       150
# Long Island          64
# Mid-Hudson           47
# Finger Lakes         27
# Western              23
# Capital District     18
# Central              14
# Southern Tier         5
# Mohawk Valley         2
# Name: economic_region, dtype: int64

# %%
region_providers = df2.groupby("economic_region").selected_taxonomy.value_counts().to_frame() \
.rename({'selected_taxonomy':'providers'},axis=1).reset_index()

# %%
region_providers
# Out:
#      economic_region                                  selected_taxonomy  \
# 0   Capital District  2084P0804X  - Psychiatry & Neurology Child & A...
# 1   Capital District  103TC2200X  - Psychologist Clinical Child & Ad...
# 2   Capital District  261QM0855X  - Clinic/Center Adolescent and Chi...
# 3   Capital District  3245S0500X  - Substance Abuse Rehabilitation F...
# 4   Capital District  364SP0810X  - Clinical Nurse Specialist Psych/...
# 5            Central  2084P0804X  - Psychiatry & Neurology Child & A...
# 6            Central  103TC2200X  - Psychologist Clinical Child & Ad...
# 7       Finger Lakes  2084P0804X  - Psychiatry & Neurology Child & A...
# 8       Finger Lakes  103TC2200X  - Psychologist Clinical Child & Ad...
# 9       Finger Lakes  364SP0810X  - Clinical Nurse Specialist Psych/...
# 10       Long Island  2084P0804X  - Psychiatry & Neurology Child & A...
# 11       Long Island  103TC2200X  - Psychologist Clinical Child & Ad...
# 12       Long Island  261QM0855X  - Clinic/Center Adolescent and Chi...
# 13       Long Island  282NC2000X  - General Acute Care Hospital Chil...
# 14        Mid-Hudson  2084P0804X  - Psychiatry & Neurology Child & A...
# 15        Mid-Hudson  103TC2200X  - Psychologist Clinical Child & Ad...
# 16        Mid-Hudson  261QM0855X  - Clinic/Center Adolescent and Chi...
# 17     Mohawk Valley  103TC2200X  - Psychologist Clinical Child & Ad...
# 18     Mohawk Valley  2084P0804X  - Psychiatry & Neurology Child & A...
# 19     New York City  2084P0804X  - Psychiatry & Neurology Child & A...
# 20     New York City  103TC2200X  - Psychologist Clinical Child & Ad...
# 21     New York City  163WP0807X  - Registered Nurse Psych/Mental He...
# 22     New York City  261QM0855X  - Clinic/Center Adolescent and Chi...
# 23     Southern Tier  103TC2200X  - Psychologist Clinical Child & Ad...
# 24     Southern Tier  2084P0804X  - Psychiatry & Neurology Child & A...
# 25     Southern Tier  364SP0810X  - Clinical Nurse Specialist Psych/...
# 26           Western  2084P0804X  - Psychiatry & Neurology Child & A...
# 27           Western  103TC2200X  - Psychologist Clinical Child & Ad...
# 28           Western  261QM0855X  - Clinic/Center Adolescent and Chi...
#
#     providers
# 0          12
# 1           3
# 2           1
# 3           1
# 4           1
# 5          10
# 6           4
# 7          17
# 8           9
# 9           1
# 10         40
# 11         21
# 12          2
# 13          1
# 14         31
# 15         14
# 16          2
# 17          1
# 18          1
# 19        101
# 20         47
# 21          1
# 22          1
# 23          2
# 24          2
# 25          1
# 26         14
# 27          8
# 28          1

# %%
df1.head()
# Out:
#          eligibility_year  eligibility_month   economic_region aid_category  \
# 2194273              2021                  8  Capital District          SSI
# 2194274              2021                  8  Capital District          SSI
# 2194275              2021                  8  Capital District          SSI
# 2194276              2021                  8  Capital District          SSI
# 2194277              2021                  8  Capital District          SSI
#
#         dual_eligible managed_care_vs._fee_for_service        plan_name  \
# 2194273            NO                              FFS  FEE-FOR-SERVICE
# 2194274            NO                              FFS  FEE-FOR-SERVICE
# 2194275            NO                              FFS  FEE-FOR-SERVICE
# 2194276            NO                              FFS  FEE-FOR-SERVICE
# 2194277            NO                              FFS  FEE-FOR-SERVICE
#
#                plan_type  gender age_group             race  \
# 2194273  FEE-FOR-SERVICE  Female     00-20            ASIAN
# 2194274  FEE-FOR-SERVICE  Female     00-20            BLACK
# 2194275  FEE-FOR-SERVICE  Female     00-20         HISPANIC
# 2194276  FEE-FOR-SERVICE  Female     00-20  NATIVE AMERICAN
# 2194277  FEE-FOR-SERVICE  Female     00-20            OTHER
#
#          number_of_recipients
# 2194273                    11
# 2194274                    41
# 2194275                    40
# 2194276                     1
# 2194277                    74

# %%
region_child_enrollees = df1.query('age_group =="00-20"').groupby(["economic_region"]).number_of_recipients.sum().to_frame().reset_index()
region_child_enrollees
# Out:
#      economic_region  number_of_recipients
# 0   Capital District                 96067
# 1            Central                 85123
# 2       Finger Lakes                124357
# 3        Long Island                232259
# 4         Mid-Hudson                259197
# 5      Mohawk Valley                 58962
# 6      New York City               1294219
# 7      North Country                 41475
# 8              Other                   730
# 9      Southern Tier                 65519
# 10           Western                152687

# %%
### Merge the providers by region and the enrollees by region

region_merge = region_providers.merge(region_child_enrollees, how="left", left_on="economic_region", right_on="economic_region")

# %%
region_merge.head()
# Out:
#     economic_region                                  selected_taxonomy  \
# 0  Capital District  2084P0804X  - Psychiatry & Neurology Child & A...
# 1  Capital District  103TC2200X  - Psychologist Clinical Child & Ad...
# 2  Capital District  261QM0855X  - Clinic/Center Adolescent and Chi...
# 3  Capital District  3245S0500X  - Substance Abuse Rehabilitation F...
# 4  Capital District  364SP0810X  - Clinical Nurse Specialist Psych/...
#
#    providers  number_of_recipients
# 0         12                 96067
# 1          3                 96067
# 2          1                 96067
# 3          1                 96067
# 4          1                 96067

# %%
### Get a rate
region_merge['rate'] = (region_merge.number_of_recipients / region_merge.providers).round()

# %% [markdown]
# ## Child Mental Health Providers By Region in order of worst rate (1 provider for every XXX children)

# %%
region_merge.sort_values(["selected_taxonomy",'rate'], ascending=False)
# Out:
#      economic_region                                  selected_taxonomy  \
# 9       Finger Lakes  364SP0810X  - Clinical Nurse Specialist Psych/...
# 4   Capital District  364SP0810X  - Clinical Nurse Specialist Psych/...
# 25     Southern Tier  364SP0810X  - Clinical Nurse Specialist Psych/...
# 3   Capital District  3245S0500X  - Substance Abuse Rehabilitation F...
# 13       Long Island  282NC2000X  - General Acute Care Hospital Chil...
# 22     New York City  261QM0855X  - Clinic/Center Adolescent and Chi...
# 28           Western  261QM0855X  - Clinic/Center Adolescent and Chi...
# 16        Mid-Hudson  261QM0855X  - Clinic/Center Adolescent and Chi...
# 12       Long Island  261QM0855X  - Clinic/Center Adolescent and Chi...
# 2   Capital District  261QM0855X  - Clinic/Center Adolescent and Chi...
# 18     Mohawk Valley  2084P0804X  - Psychiatry & Neurology Child & A...
# 24     Southern Tier  2084P0804X  - Psychiatry & Neurology Child & A...
# 19     New York City  2084P0804X  - Psychiatry & Neurology Child & A...
# 26           Western  2084P0804X  - Psychiatry & Neurology Child & A...
# 5            Central  2084P0804X  - Psychiatry & Neurology Child & A...
# 14        Mid-Hudson  2084P0804X  - Psychiatry & Neurology Child & A...
# 0   Capital District  2084P0804X  - Psychiatry & Neurology Child & A...
# 7       Finger Lakes  2084P0804X  - Psychiatry & Neurology Child & A...
# 10       Long Island  2084P0804X  - Psychiatry & Neurology Child & A...
# 21     New York City  163WP0807X  - Registered Nurse Psych/Mental He...
# 17     Mohawk Valley  103TC2200X  - Psychologist Clinical Child & Ad...
# 23     Southern Tier  103TC2200X  - Psychologist Clinical Child & Ad...
# 1   Capital District  103TC2200X  - Psychologist Clinical Child & Ad...
# 20     New York City  103TC2200X  - Psychologist Clinical Child & Ad...
# 6            Central  103TC2200X  - Psychologist Clinical Child & Ad...
# 27           Western  103TC2200X  - Psychologist Clinical Child & Ad...
# 15        Mid-Hudson  103TC2200X  - Psychologist Clinical Child & Ad...
# 8       Finger Lakes  103TC2200X  - Psychologist Clinical Child & Ad...
# 11       Long Island  103TC2200X  - Psychologist Clinical Child & Ad...
#
#     providers  number_of_recipients       rate
# 9           1                124357   124357.0
# 4           1                 96067    96067.0
# 25          1                 65519    65519.0
# 3           1                 96067    96067.0
# 13          1                232259   232259.0
# 22          1               1294219  1294219.0
# 28          1                152687   152687.0
# 16          2                259197   129598.0
# 12          2                232259   116130.0
# 2           1                 96067    96067.0
# 18          1                 58962    58962.0
# 24          2                 65519    32760.0
# 19        101               1294219    12814.0
# 26         14                152687    10906.0
# 5          10                 85123     8512.0
# 14         31                259197     8361.0
# 0          12                 96067     8006.0
# 7          17                124357     7315.0
# 10         40                232259     5806.0
# 21          1               1294219  1294219.0
# 17          1                 58962    58962.0
# 23          2                 65519    32760.0
# 1           3                 96067    32022.0
# 20         47               1294219    27537.0
# 6           4                 85123    21281.0
# 27          8                152687    19086.0
# 15         14                259197    18514.0
# 8           9                124357    13817.0
# 11         21                232259    11060.0

# %%
psyc = ["2084P0804X  - Psychiatry & Neurology Child & Adolescent Psychiatry","103TC2200X  - Psychologist Clinical Child & Adolescent"]

# %%
### I'm mostly interested in psychologist and psychiatrists right now
region_merge[region_merge.selected_taxonomy.isin(psyc)].sort_values(["selected_taxonomy",'rate'], ascending=False)
# Out:
#      economic_region                                  selected_taxonomy  \
# 18     Mohawk Valley  2084P0804X  - Psychiatry & Neurology Child & A...
# 24     Southern Tier  2084P0804X  - Psychiatry & Neurology Child & A...
# 19     New York City  2084P0804X  - Psychiatry & Neurology Child & A...
# 26           Western  2084P0804X  - Psychiatry & Neurology Child & A...
# 5            Central  2084P0804X  - Psychiatry & Neurology Child & A...
# 14        Mid-Hudson  2084P0804X  - Psychiatry & Neurology Child & A...
# 0   Capital District  2084P0804X  - Psychiatry & Neurology Child & A...
# 7       Finger Lakes  2084P0804X  - Psychiatry & Neurology Child & A...
# 10       Long Island  2084P0804X  - Psychiatry & Neurology Child & A...
# 17     Mohawk Valley  103TC2200X  - Psychologist Clinical Child & Ad...
# 23     Southern Tier  103TC2200X  - Psychologist Clinical Child & Ad...
# 1   Capital District  103TC2200X  - Psychologist Clinical Child & Ad...
# 20     New York City  103TC2200X  - Psychologist Clinical Child & Ad...
# 6            Central  103TC2200X  - Psychologist Clinical Child & Ad...
# 27           Western  103TC2200X  - Psychologist Clinical Child & Ad...
# 15        Mid-Hudson  103TC2200X  - Psychologist Clinical Child & Ad...
# 8       Finger Lakes  103TC2200X  - Psychologist Clinical Child & Ad...
# 11       Long Island  103TC2200X  - Psychologist Clinical Child & Ad...
#
#     providers  number_of_recipients     rate
# 18          1                 58962  58962.0
# 24          2                 65519  32760.0
# 19        101               1294219  12814.0
# 26         14                152687  10906.0
# 5          10                 85123   8512.0
# 14         31                259197   8361.0
# 0          12                 96067   8006.0
# 7          17                124357   7315.0
# 10         40                232259   5806.0
# 17          1                 58962  58962.0
# 23          2                 65519  32760.0
# 1           3                 96067  32022.0
# 20         47               1294219  27537.0
# 6           4                 85123  21281.0
# 27          8                152687  19086.0
# 15         14                259197  18514.0
# 8           9                124357  13817.0
# 11         21                232259  11060.0
